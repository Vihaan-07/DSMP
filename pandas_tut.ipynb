# %%
import pandas as pd
import numpy as np

# %%
countries = ['India', 'UAE', 'Pakistan', 'Oman', 'Yemen', 'UK', 'Saudi Arabia']

pd.Series(countries)
# Out:
# 0           India
# 1             UAE
# 2        Pakistan
# 3            Oman
# 4           Yemen
# 5              UK
# 6    Saudi Arabia
# dtype: object

# %%
marks = [99, 100, 98, 95]
subjects= ["Maths", "CS", 'Physics', 'Chemistry']
marks = pd.Series(marks, index=subjects)

# %%
marks.size
# Out:
# 4

# %%
marks.dtype
# Out:
# dtype('int64')

# %%
marks.name

# %%
print(marks.is_unique)
print(pd.Series([1,1,2,3,4,5,6,5,5]).is_unique)
# Out:
# True
# False

# %%
marks.index
# Out:
# Index(['Maths', 'CS', 'Physics', 'Chemistry'], dtype='object')

# %%
marks.values
# Out:
# array([ 99, 100,  98,  95])

# %%
subs_data = pd.read_csv('subs.csv').iloc[:, 0]
subs_data
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
kohli_stats = pd.read_csv('kohli_ipl.csv', index_col='match_no').iloc[:, 0]
kohli_stats
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
bolly_stats = pd.read_csv('bollywood.csv', index_col='movie').iloc[:, 0]
bolly_stats
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
bolly_stats.sample(10)
# Out:
# movie
# Son of Sardaar                         Ajay Devgn
# The Dirty Picture                     Vidya Balan
# No One Killed Jessica                Rani Mukerji
# Krazzy 4                              Juhi Chawla
# Raman Raghav 2.0              Nawazuddin Siddiqui
# Antardwand                    Raj Singh Chaudhary
# Sunday (2008 film)                     Ajay Devgn
# Thugs of Hindostan                     Aamir Khan
# Tees Maar Khan (2010 film)           Akshay Kumar
# Ek: The Power of One                   Bobby Deol
# Name: lead, dtype: object

# %%
bolly_stats.value_counts()
# Out:
# lead
# Akshay Kumar            48
# Amitabh Bachchan        45
# Ajay Devgn              38
# Salman Khan             31
# Sanjay Dutt             26
#                         ..
# Tanishaa Mukerji         1
# Tanuja                   1
# Ankit                    1
# Rakhee Gulzar            1
# Geetika Vidya Ohlyan     1
# Name: count, Length: 566, dtype: int64

# %%
subs_data.sort_values(ascending=False)
# Out:
# 330    396
# 331    312
# 168    306
# 233    301
# 280    295
#       ...
# 14      39
# 19      37
# 24      35
# 6       33
# 42      33
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
kohli_stats.count()
# Out:
# np.int64(215)

# %%
kohli_stats.sum()
# Out:
# np.int64(6634)

# %%
subs_data.sum()
# Out:
# np.int64(49510)

# %%
kohli_stats.mean()
# Out:
# np.float64(30.855813953488372)

# %%
kohli_stats.median()
# Out:
# np.float64(24.0)

# %%
bolly_stats.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
kohli_stats.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64
